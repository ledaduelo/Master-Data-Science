# %%
import pandas as pd

# %%
b = pd.read_csv('bookings.csv.bz2',sep='^', chunksize=1e5)

# %%
b

# %%
for chunk in b:
    print (chunk.__class__)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
lista = []
for chunk in b:
    lista.append(chunk[['arr_port','pax']].groupby('arr_port').sum().sort("pax",ascending=False))

# %%
lista
# Out:
# [           pax
#  arr_port
#  LHR       1006
#  MCO        861
#  JFK        795
#  LAX        761
#  BKK        747
#  LAS        732
#  SFO        705
#  ORD        686
#  CDG        676
#  DXB        587
#  MIA        585
#  EWR        539
#  DFW        514
#  ATL        498
#  IST        497
#  FCO        479
#  LGA        472
#  CUN        447
#  FLL        435
#  DEN        403
#  HKG        400
#  BOS        387
#  DCA        381
#  PHX        377
#  PEK        375
#  SEA        363
#  BOM        361
#  MAD        356
#  HNL        352
#  MUC        344
#  ...        ...
#  EZS         -2
#  URY         -2
#  IXL         -2
#  XUZ         -2
#  YAY         -2
#  HDS         -2
#  MAO         -3
#  IGU         -3
#  HMB         -3
#  ASU         -3
#  JHB         -3
#  ASR         -4
#  XMB         -4
#  RFP         -4
#  LDH         -4
#  FSC         -5
#  BOB         -5
#  STS         -6
#  KSN         -6
#  LGK         -6
#  KLU         -6
#  RAR         -8
# ...

# %%
dchunk = pd.DataFrame(chunk.arr_port,chunk.pax)

# %%
dchunk
# Out:
#      arr_port
# pax
#  2   LAS
#  2   LAS
#  2   LAS
#  1   LAS
#  1   LAS
# -1        NaN
#  1   LAS
#  1   LAS
#  1   LAS
#  1   LAS

# %%
d1 = dchunk
d2 = dchunk
d3 = dchunk
d4 = dchunk

pd.concat([d1,d2,d3,d4]).count()
# Out:
# arr_port    36
# dtype: int64

# %%
l = []
for mydf in [d1,d2,d3,d4]:
    l.append(mydf)

# %%
len(l)
# Out:
# 4

# %%
pd.concat(l)
# Out:
#      arr_port
# pax
#  2   LAS
#  2   LAS
#  2   LAS
#  1   LAS
#  1   LAS
# -1        NaN
#  1   LAS
#  1   LAS
#  1   LAS
#  1   LAS
#  2   LAS
#  2   LAS
#  2   LAS
#  1   LAS
#  1   LAS
# -1        NaN
#  1   LAS
#  1   LAS
#  1   LAS
#  1   LAS
#  2   LAS
#  2   LAS
#  2   LAS
#  1   LAS
#  1   LAS
# -1        NaN
#  1   LAS
#  1   LAS
#  1   LAS
#  1   LAS
#  2   LAS
#  2   LAS
#  2   LAS
#  1   LAS
#  1   LAS
# -1        NaN
#  1   LAS
#  1   LAS
#  1   LAS
#  1   LAS

# %%
l.groupby('arr_port').sum().sort('pax',ascending=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-1c464c093d9b> in <module>()
# ----> 1 l.groupby('arr_port').sum().sort('pax',ascending="False")
#
# AttributeError: 'list' object has no attribute 'groupby'

# %%
listatop = []
for chunk in b:
    s = chunk.groupby('arr_port').sum('pax')
    listatop.append(s) 
    
#error podemos ignorar aeropuertos no en cada top 10
    
todoslosDf = pd.concat(lista)

sTodos = todosDf.groupby('arr_port').sum('pax')
sTodos.reset_index().sort('pax',ascending=False).head()

# %%
firstchunk = b.get_chunk
todoDf = chunk.groupby ('arr_port').sum('pax')

for chunk in b:
    s = chunk.groupby('arr_port')
    s.sum('pax')
    c = pd.concat(s.todosDf)
    todosDf = c.groupby('arr_port').sum('pax').reset_index()
    
#error podemos ignorar aeropuertos no en cada top 10
    
todoslosDf = pd.concat(lista)

sTodos = todosDf.groupby('arr_port').sum('pax')
sTodos.reset_index().sort('pax',ascending=False).head()

# %%
c = pd.Dataframe([])
hePasadoYaporchunk1 = False


for chunk in b:
    print ('procesando chunk')
    s = chunk.groupby('arr_port').pax.sum().reset_index()
    if hePasadoYaporchunk1:
        c = pd.concat([s,todosDf])
    else:
        c = s
        hePasadoYaporchunk1=True
    todosDf = c.groupby('arr_port').pax.sum().reset_index()
    
#error podemos ignorar aeropuertos no en cada top 10
    
todosDf.sort('pax',ascending=False).head()
# Out:
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# procesando chunk
# ...
